# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
# !git clone https://github.com/lang-uk/ner-uk.git 
# !cd ner-uk; scripts/train_stanza_ner.sh 
# !cp ner-uk/workspace/stanza/uk_languk_nertagger.pt /gdrive/MyDrive/
